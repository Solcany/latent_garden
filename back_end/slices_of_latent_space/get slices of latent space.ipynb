# %%
import numpy as np 
import glob
import os 
import umap
import numpy as np

# %%
total_sample_size = 100
slice_size = 10
sample_size_per_slice = total_sample_size / slices_size
latent_vector_size = 128
umap_neighbours = 50
umap_min_distatnce = 0.1
umap_dimensions = 2
output_path = "./output/"
csv_filename = "random_nums_3d_embeddings"
csv_header = "x, y, z"
csv_comments = "" # should the csv header have any text before the labels? (like '#' for python comment)
csv_fmt = "%f" #fmt "%f" ensures floats are not saved in the sci annotation format to to the csv file

# %%
# def main():
# 	# create output folder
# 	if not os.path.isdir(output_path):
# 	    os.mkdir(output_path)

total_sample = np.random.normal(0, 1, (total_sample_size, latent_vector_size))

# %%
	print("Running umap")	
	# get embeddings
	reducer = umap.UMAP(n_neighbors=umap_neighbours, min_dist=umap_min_distatnce, n_components=umap_dimensions)
	embeddings = reducer.fit_transform(total_sample)
    
	# create 3rd column for z index, where z is always 0
# 	embeddings = np.insert(embeddings, 2, 0, 1)


# 	# save the embeddings
# 	csv_path = os.path.join(output_path, csv_filename + ".csv")
# 	np.savetxt(csv_path, 
# 				embeddings, 
# 				delimiter=",", 
# 				header=csv_header, 
# 				comments=csv_comments,				
# 				fmt=csv_fmt) 
# 	print("Umap embeddings saved at: " + csv_path)
# Out:
# Running umap
# OMP: Info #273: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
s = np.random.choice(embeddings, size=(10,2), replace=False)
#embeddings.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/zj/f_wv_4b16pd3hxw8qg93mh1m0000gn/T/ipykernel_10267/3396373676.py in <module>
# ----> 1 s = np.random.choice(embeddings, size=(10,2), replace=False)
#       2 #embeddings.shape
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be 1-dimensional

# %%
arr = np.array([1,2,3,4])
s =  np.random.choice(arr, size=2, replace=False) # replace=False - each value can be selected only once
print(arr)
print(s)
# get random indexes
# use them to get items from total sample to slice arr
# use them to delete items from total sample
# consider boolean mask to do the removal?
# Out:
# [1 2 3 4]
# [1 1]

# %%
indexes = np.arange(0, 12)
slice_size = 3
for _ in range(4):
    selection = np.random.choice(indexes, size=slice_size, replace=False)
    res = np.flatnonzero(np.isin(indexes, selection))
    indexes = np.delete(indexes, res)
    print("all indexes: ")
    print(indexes)
    print("selection: ")
    print(selection)
    print("deletion indexes: ")
    print(res)

#np.where(indexes == selection)
#selection_indixes = np.array([np.where(indexes == s) for s in selection])

#print(selection)
#print(selection_indixes)
#indexes1 = np.delete(indexes, selection)
#np.where(indexes == [0,1])
# Out:
# all indexes:
# [ 0  1  2  4  5  7  9 10 11]
# selection:
# [3 8 6]
# deletion indexes:
# [3 6 8]
# all indexes:
# [ 0  1  4  9 10 11]
# selection:
# [7 5 2]
# deletion indexes:
# [2 4 5]
# all indexes:
# [ 0  9 10]
# selection:
# [ 1 11  4]
# deletion indexes:
# [1 2 5]
# all indexes:
# []
# selection:
# [10  9  0]
# deletion indexes:
# [0 1 2]

# %%
embs = np.copy(embeddings)
embs_indexes = np.arange(embs.shape[0])

#assert(total_sample_size / slice_size == 0)

print(total_sample_size / slice_size)

for _ in range(total_sample_size/slice_size):
    embeddings_slice_indexes = np.random.choice(embs_indexes,size=slice_size, replace=False)
    slice_indexes = np.flatnonzero(np.isin(embs, embeddings_slice_indexes))
    embs_slice = embs[embeddings_slice_indexes]
    embs_indexes = np.delete(embs_indexes, slice_indexes)
    print(embs_slice)
# Out:
# 33.333333333333336
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/zj/f_wv_4b16pd3hxw8qg93mh1m0000gn/T/ipykernel_10267/1897193985.py in <module>
#       6 print(total_sample_size / slice_size)
#       7
# ----> 8 for _ in range(total_sample_size/slice_size):
#       9     embeddings_slice_indexes = np.random.choice(embs_indexes,size=slice_size, replace=False)
#      10     slice_indexes = np.flatnonzero(np.isin(embs, embeddings_slice_indexes))
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
np.empty((100, 4)) # x, y, id, slice id
# Out:
# array([[4.04738577e-320, 1.45452926e-320, 0.00000000e+000,
#         6.94656463e-310],
#        [4.94065646e-324, 6.94656463e-310, 6.94635322e-310,
#         2.14087431e-314],
#        [6.94635322e-310, 6.94656463e-310, 8.48798317e-314,
#         1.38338381e-322],
#        [2.14075712e-314, 6.94635322e-310, 2.15449800e-314,
#         1.90979621e-313],
#        [4.94065646e-324, 6.94656463e-310, 8.39911598e-323,
#         2.14000788e-314],
#        [7.90505033e-323, 6.94656463e-310, 3.18299369e-313,
#         0.00000000e+000],
#        [0.00000000e+000, 2.12199579e-313, 6.94656463e-310,
#         6.94656463e-310],
#        [6.94656463e-310, 1.90979621e-313, 4.44659081e-323,
#         6.94656463e-310],
#        [6.94656463e-310, 6.94656463e-310, 6.94656463e-310,
#         6.94656463e-310],
#        [6.94656463e-310, 6.94656463e-310, 6.94656463e-310,
#         6.94656463e-310],
#        [4.94065646e-324, 6.94656463e-310, 2.12199580e-314,
#         2.15441680e-314],
#        [6.94635322e-310, 4.88059032e-313, 8.48798317e-314,
#         6.94635322e-310],
#        [2.15354013e-314, 6.94635322e-310, 2.12199579e-313,
#         3.39519327e-313],
#        [6.94635322e-310, 6.94656463e-310, 2.14592390e-314,
#         6.79038653e-313],
#        [3.39519327e-313, 1.23516411e-322, 6.94656463e-310,
#         2.14593569e-314],
#        [7.85138443e-313, 3.39519327e-313, 4.94065646e-324,
#         6.94656463e-310],
#        [1.38338381e-322, 2.15449800e-314, 6.94635322e-310,
#         6.94656463e-310],
#        [7.00258611e-313, 9.88131292e-324, 6.94656463e-310,
#         6.94656463e-310],
#        [6.94635322e-310, 2.43747521e-314, 6.94635322e-310,
#         6.94656463e-310],
#        [9.97338022e-313, 2.14074286e-314, 6.94656463e-310,
#         2.12199580e-314],
#        [2.13980811e-314, 8.89318163e-323, 1.48539705e-313,
#         1.42173718e-312],
#        [2.14065116e-314, 6.94656463e-310, 7.90505033e-323,
#         6.94656463e-310],
#        [6.94656463e-310, 6.94656463e-310, 3.39519327e-313,
#         2.96439388e-323],
#        [6.94656463e-310, 6.94656463e-310, 2.14131949e-314,
#         0.00000000e+000],
#        [0.00000000e+000, 8.48798317e-314, 4.94065646e-324,
#         6.94656463e-310],
#        [1.38338381e-322, 2.14224647e-314, 5.72938864e-313,
#         8.89318163e-323],
#        [8.48798317e-314, 1.38338381e-322, 2.15354013e-314,
#         6.79038653e-313],
#        [8.89318163e-323, 2.12199579e-313, 1.23516411e-322,
#         6.94656463e-310],
#        [2.15280021e-314, 4.94065646e-324, 2.12199579e-313,
#         4.94065646e-324],
#        [6.94656463e-310, 8.91238232e-313, 2.15354013e-314,
#         2.12199579e-314],
#        [0.00000000e+000, 5.30498948e-313, 9.97338022e-313,
#         6.94656463e-310],
#        [2.14965129e-314, 4.94065646e-324, 5.30498948e-313,
#         9.88131292e-324],
#        [6.94656463e-310, 6.94656463e-310, 1.38338381e-322,
#         2.15449800e-314],
#        [1.20953760e-312, 8.89318163e-323, 7.00258611e-313,
#         1.38338381e-322],
#        [2.15441680e-314, 1.31563739e-312, 1.43279037e-322,
#         8.91238232e-313],
#        [0.00000000e+000, 0.00000000e+000, 1.27319748e-313,
#         6.94656463e-310],
#        [6.94656463e-310, 6.94656463e-310, 5.30498948e-313,
#         0.00000000e+000],
#        [0.00000000e+000, 7.90505033e-323, 6.94656463e-310,
#         6.94656463e-310],
#        [6.94656463e-310, 2.12199579e-313, 2.96439388e-323,
#         6.94656463e-310],
#        [6.94656463e-310, 1.38338381e-322, 2.15354013e-314,
#         4.94065646e-324],
#        [8.48798317e-314, 4.94065646e-324, 6.94656463e-310,
#         6.94635322e-310],
#        [2.15449800e-314, 9.88131292e-324, 2.54639495e-313,
#         8.48798317e-314],
#        [6.94635322e-310, 2.15354013e-314, 4.94065646e-324,
#         2.54639495e-313],
#        [2.97079411e-313, 6.94635322e-310, 6.94656463e-310,
#         2.14079254e-314],
#        [6.94635322e-310, 2.97079411e-313, 9.88131292e-324,
#         6.94656463e-310],
#        [6.94656463e-310, 6.15378780e-313, 2.15449800e-314,
#         2.12199579e-314],
#        [4.94065646e-324, 5.09278990e-313, 8.06358401e-313,
#         2.14224647e-314],
#        [2.12199579e-314, 0.00000000e+000, 7.00258611e-313,
#         0.00000000e+000],
#        [0.00000000e+000, 6.94635322e-310, 6.94656463e-310,
#         6.94656463e-310],
#        [6.94656463e-310, 2.97079411e-313, 9.76118064e-313,
#         6.94656463e-310],
#        [6.94656463e-310, 0.00000000e+000, 0.00000000e+000,
#         1.14587773e-312],
#        [8.48798317e-314, 6.94635322e-310, 2.14075624e-314,
#         6.94635322e-310],
#        [6.94656463e-310, 8.48798317e-314, 4.94065646e-324,
#         6.94656463e-310],
#        [6.94635322e-310, 2.47454244e-314, 0.00000000e+000,
#         0.00000000e+000],
#        [2.12199579e-313, 0.00000000e+000, 0.00000000e+000,
#         6.94635322e-310],
#        [6.94656463e-310, 6.94656463e-310, 6.94656463e-310,
#         8.48798317e-314],
#        [1.08694442e-322, 6.94656463e-310, 2.15354013e-314,
#         4.94065646e-324],
#        [0.00000000e+000, 2.12199579e-313, 8.48798317e-314,
#         6.94635322e-310],
#        [2.14075624e-314, 4.94065646e-324, 2.12199579e-313,
#         8.48798317e-314],
#        [4.94065646e-324, 6.94656463e-310, 1.38338381e-322,
#         2.15449800e-314],
#        [4.94065646e-324, 2.15449800e-314, 2.12199579e-313,
#         0.00000000e+000],
#        [0.00000000e+000, 7.90505033e-323, 6.94656463e-310,
#         6.94656463e-310],
#        [6.94656463e-310, 8.48798317e-314, 1.08694442e-322,
#         6.94656463e-310],
#        [6.94656463e-310, 6.94656463e-310, 2.12199579e-313,
#         2.96439388e-323],
#        [8.48798317e-314, 6.94635322e-310, 2.14075624e-314,
#         4.94065646e-324],
#        [0.00000000e+000, 8.48798317e-314, 4.94065646e-324,
#         6.94656463e-310],
#        [8.89318163e-323, 2.47454297e-314, 4.94065646e-323,
#         4.94065646e-324],
#        [2.12199579e-313, 0.00000000e+000, 0.00000000e+000,
#         7.90505033e-323],
#        [6.94656463e-310, 6.94656463e-310, 6.94656463e-310,
#         8.48798317e-314],
#        [1.08694442e-322, 6.94656463e-310, 2.14069701e-314,
#         4.94065646e-324],
#        [1.27319748e-313, 7.90505033e-323, 8.48798317e-314,
#         6.94635322e-310],
#        [2.14075624e-314, 4.94065646e-324, 1.08694442e-322,
#         8.48798317e-314],
#        [4.94065646e-324, 6.94656463e-310, 1.38338381e-322,
#         2.15441680e-314],
#        [4.94065646e-324, 4.94065646e-324, 2.12199579e-313,
#         0.00000000e+000],
#        [0.00000000e+000,             nan, 6.94656463e-310,
#         6.94656463e-310],
#        [6.94656463e-310, 8.48798317e-314, 6.94656542e-310,
#         6.94656463e-310],
#        [2.54639495e-313, 6.94635322e-310, 6.94656463e-310,
#         2.14592390e-314],
#        [8.48798317e-314, 2.54639495e-313, 2.14075624e-314,
#         6.94635322e-310],
#        [2.14593569e-314, 8.48798317e-314, 4.94065646e-324,
#         6.94656463e-310],
#        [6.94635322e-310, 2.47452248e-314, 6.94656463e-310,
#         6.94656463e-310],
#        [2.12199579e-313, 0.00000000e+000, 0.00000000e+000,
#         7.90505033e-323],
#        [6.94656463e-310, 6.94656463e-310, 6.94656463e-310,
#         8.48798317e-314],
#        [6.94635322e-310, 6.94656463e-310,             nan,
#         2.14000786e-314],
#        [6.94656923e-310,             nan, 8.48798317e-314,
#         2.12199580e-314],
#        [2.14075624e-314, 6.94635322e-310, 2.14065116e-314,
#         8.48798317e-314],
#        [4.94065646e-324, 6.94656463e-310,             nan,
#         2.14224647e-314],
#        [4.94065646e-324,             nan, 2.12199579e-313,
#         0.00000000e+000],
#        [0.00000000e+000, 6.94635322e-310, 6.94656463e-310,
#         6.94656463e-310],
#        [6.94656463e-310, 8.48798317e-314,             nan,
#         6.94656463e-310],
#        [6.94656463e-310,             nan, 6.94656521e-310,
#         0.00000000e+000],
#        [8.48798317e-314, 0.00000000e+000, 0.00000000e+000,
#                     nan],
#        [6.94656463e-310, 6.94656463e-310, 6.94656463e-310,
#         6.94656463e-310],
#        [1.38338381e-322, 3.95252517e-323, 6.94635322e-310,
#         6.94656463e-310],
#        [2.12199579e-313, 6.94635322e-310, 6.94656463e-310,
#         2.14079254e-314],
#        [6.94635322e-310, 2.12199579e-313, 9.88131292e-324,
#         6.94656463e-310],
#        [6.94656463e-310, 0.00000000e+000, 0.00000000e+000,
#         1.38338381e-322],
#        [2.15449800e-314, 4.94065646e-324, 6.94656462e-310,
#         4.24399158e-313],
#        [6.94656542e-310, 2.15441680e-314,             nan,
#         0.00000000e+000],
#        [6.15378779e-313, 7.90505033e-323, 6.94656463e-310,
#         6.94656463e-310],
#        [6.94656463e-310, 2.12199579e-313,             nan,
#         6.94656463e-310]])
